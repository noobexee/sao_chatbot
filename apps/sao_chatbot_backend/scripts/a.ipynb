# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.columns
# Out:
# Index(['type', 'title', 'version', 'announce_date', 'effective_date', 'status',
#        'pdf_file_path', 'is_latest', 'is_snapshot'],
#       dtype='object')

# %%
df.head(1)
# Out:
#       type                                              title  version  \
# 0  ระเบียบ  ระเบียบสำนักงานการตรวจเงินแผ่นดินว่าด้วยการตรว...        1
#
#   announce_date effective_date          status  \
# 0    11/08/2566     29/09/2566  need_attention
#
#                                        pdf_file_path  is_latest  is_snapshot
# 0  ระเบียบสำนักงานการตรวจเงินแผ่นดินว่าด้วยการตรว...      False        False
